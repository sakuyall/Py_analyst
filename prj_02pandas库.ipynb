# %% [markdown]
# ## 6/23/26 pandas

# %% [markdown]
# ### 创建Series

# %%
import pandas as pd
# 使用列表创建
s = pd.Series([10, 2, 3,  4, 5])
print(s)

# 自定义索引与name
s = pd.Series([10, 2, 3, 4, 5], index = [6, 'a', 8, 9, 100], name = '名字')
print(s)
# Out:
# 0    10
# 1     2
# 2     3
# 3     4
# 4     5
# dtype: int64
# 6      10
# a       2
# 8       3
# 9       4
# 100     5
# Name: 名字, dtype: int64

# %%
# 使用字典来创建
s = pd.Series({'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}, name = 'name111')
print(s)

# 从原序列按照index获取对应组合创建新series
s1 = pd.Series(s, index = ['a', 'c'])
print(s1)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: name111, dtype: int64
# a    1
# c    3
# Name: name111, dtype: int64

# %% [markdown]
# ### 属性

# %%
# 索引与值
print(s.index, s.values)

# 形状, 维数, 元素个数, 元素类型
print(s.shape, s.ndim, s.size, s.dtype)

# 名字
print(s.name)

# 显式索引(标签)及切片, 隐式索引(下标), 单个元素访问(不可切片)
print(s.loc['a'], '\n', s.loc['a': 'c'], s.iloc[0])
print(s.at['a'], s.iat[0])

# 不建议在该库下使用python原生索引方式, 防止显式与隐式冲突
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='str') [1 2 3 4 5]
# (5,) 1 5 int64
# name111
# 1
#  a    1
# b    2
# c    3
# Name: name111, dtype: int64 1
# 1 1

# %%
# 返回series前五行的内容
print(s.head())
# 返回series后五行的内容
print(s.tail())
# 可传入参数, 返回设定的行数, 默认为5
# 用于快捷查看元素内容
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: name111, dtype: int64
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: name111, dtype: int64

# %% [markdown]
# ### 常见函数

# %%
import numpy as np
# pandas会将np的缺失值及原生的None全记作NaN
s = pd.Series([10, 2, np.nan, None, 3, 4, 5], index = ['a', 'b', 'c', 'd', 'e', 'f', 'g'], name = 'Data')

s.head(3).to_frame()    # 不打印, 直接获取表格形式, 并渲染
# Out:
#    Data
# a  10.0
# b   2.0
# c   NaN

# %%
# 查看所有描述性信息
s.describe().to_frame()
# 几种统计方法的值都在这里, 写法与np一样, 注意计算时排除缺失值
# Out:
#             Data
# count   5.000000
# mean    4.800000
# std     3.114482
# min     2.000000
# 25%     3.000000
# 50%     4.000000
# 75%     5.000000
# max    10.000000

# %%
# 获取元素个数(忽略缺失值)
print(s.count())

# 两种获取索引的方法
print(s.keys())
print(s.index)

# 判断每一个元素是否为缺失值
s.isna().to_frame()

# 检查series的每个元素是否在给定集合中
s.isin([4, 5, 6]).to_frame()
# Out:
# 5
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g'], dtype='str')
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g'], dtype='str')
#     Data
# a  False
# b  False
# c  False
# d  False
# e  False
# f   True
# g   True

# %%
# 分位数写法与np有区别
s.quantile(0.25)
# Out:
# np.float64(3.0)

# %%
# 众数, 按照出现频率计算
print(s.mode())

# 列表元素计数
print(s.value_counts())

# 按值与按索引排序
print(s.sort_values())
print(s.sort_index())
# Out:
# 0     2.0
# 1     3.0
# 2     4.0
# 3     5.0
# 4    10.0
# Name: Data, dtype: float64
# Data
# 10.0    1
# 2.0     1
# 3.0     1
# 4.0     1
# 5.0     1
# Name: count, dtype: int64
# b     2.0
# e     3.0
# f     4.0
# g     5.0
# a    10.0
# c     NaN
# d     NaN
# Name: Data, dtype: float64
# a    10.0
# b     2.0
# c     NaN
# d     NaN
# e     3.0
# f     4.0
# g     5.0
# Name: Data, dtype: float64

# %%
# 去重
print(s.drop_duplicates())
# 这里对缺失值进行了去重

# 去重后的元素与个数
print(s.nunique())
# Out:
# a    10.0
# b     2.0
# c     NaN
# e     3.0
# f     4.0
# g     5.0
# Name: Data, dtype: float64
# 5

# %% [markdown]
# ### 6/25/26 series案例

# %% [markdown]
# 1 学生成绩统计\
# 创建包含10名学生的Series, 成绩范围在50-100之间\
# 计算平均分 最高分 最低分 找出高于平均分的人数

# %%
np.random.seed(42)
scores = pd.Series(np.random.randint(50, 101, 10), index = ['学生'+str(i) for i in range(1, 11)])

print(scores)
print(scores.mean())
print(scores.max())
print(scores.min())
mean = scores.mean()
print(len(scores[scores > mean]))    # 布尔索引筛选, 或使用.count()代替len计数
# Out:
# 学生1     88
# 学生2     78
# 学生3     64
# 学生4     92
# 学生5     57
# 学生6     70
# 学生7     88
# 学生8     68
# 学生9     72
# 学生10    60
# dtype: int32
# 73.7
# 92
# 57
# 4

# %% [markdown]
# 2 温度数据分析\
# 给定某城市一周内每天最高温度series\
# 找出温度超过30的天数\
# 计算平均温度 将温度从高到低排序\
# 找出温度变化最大的两天

# %%
tem = pd.Series([28, 31, 29, 32, 30, 27, 33], index = ['周一', '周二', '周三', '周四', '周五', '周六', '周日'])

print(tem[tem > 30].count())
print(tem.mean())
print(tem.sort_values(ascending = False))    # 是否升序排列

t = tem.diff().abs()    # 获取后一个元素与前一个元素的差值
date = t.sort_values(ascending = False).keys()
print(date)
print(*date[:2])   # 这和前边显式隐式索引不一样, 这里已经选取了key()列
# Out:
# 3
# 30.0
# 周日    33
# 周四    32
# 周二    31
# 周五    30
# 周三    29
# 周一    28
# 周六    27
# dtype: int64
# Index(['周日', '周二', '周六', '周四', '周三', '周五', '周一'], dtype='str')
# 周日 周二

# %% [markdown]
# 3 股票价格分析\
# 给定10天收盘价\
# 计算每日收益率, 当日 / 前日 - 1\
# 找出收益率最高和最低的日期\
# 计算波动率(标准差)

# %%
prices = pd.Series([102.3, 103.5, 105.1, 104.8, 106.2, 107.0, 106.5, 108.1, 109.3, 110.2], \
                   index = pd.date_range('2023-01-01', periods = 10))    # 日期序列的函数
print(prices)
pct = prices.pct_change()    # 收益率的内置函数
print(pct)
print(pct.max(), pct.min())
print(pct.idxmax(), pct.idxmin())
print(pct.std())
# Out:
# 2023-01-01    102.3
# 2023-01-02    103.5
# 2023-01-03    105.1
# 2023-01-04    104.8
# 2023-01-05    106.2
# 2023-01-06    107.0
# 2023-01-07    106.5
# 2023-01-08    108.1
# 2023-01-09    109.3
# 2023-01-10    110.2
# Freq: D, dtype: float64
# 2023-01-01         NaN
# 2023-01-02    0.011730
# 2023-01-03    0.015459
# 2023-01-04   -0.002854
# 2023-01-05    0.013359
# 2023-01-06    0.007533
# 2023-01-07   -0.004673
# 2023-01-08    0.015023
# 2023-01-09    0.011101
# 2023-01-10    0.008234
# Freq: D, dtype: float64
# 0.015458937198067568 -0.004672897196261627
# 2023-01-03 00:00:00 2023-01-07 00:00:00
# 0.007373623845361105

# %% [markdown]
# 4 销售数据分析\
# 计算季度平均销量, 找出销量最高月份\
# 计算月环比增长率\
# 找出连续增长超过两个月的月份
